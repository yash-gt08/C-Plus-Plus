# %% [markdown]
# <a href="https://colab.research.google.com/github/yash-gt08/C-Plus-Plus/blob/master/Auto_Code_Generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Install Required Libraries

# %%
pip install torch transformers accelerate

# %% [markdown]
# Load GPT-Neo Model

# %%
from transformers import GPTNeoForCausalLM, GPT2Tokenizer
import torch

# %% [markdown]
# Load Tokenizer

# %%
tokenizer = GPT2Tokenizer.from_pretrained("EleutherAI/gpt-neo-1.3B")

# %% [markdown]
# Load Model

# %%
model = GPTNeoForCausalLM.from_pretrained("EleutherAI/gpt-neo-1.3B")
model.eval()
# Out:
# GPTNeoForCausalLM(
#   (transformer): GPTNeoModel(
#     (wte): Embedding(50257, 2048)
#     (wpe): Embedding(2048, 2048)
#     (drop): Dropout(p=0.0, inplace=False)
#     (h): ModuleList(
#       (0-23): 24 x GPTNeoBlock(
#         (ln_1): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#         (attn): GPTNeoAttention(
#           (attention): GPTNeoSelfAttention(
#             (attn_dropout): Dropout(p=0.0, inplace=False)
#             (resid_dropout): Dropout(p=0.0, inplace=False)
#             (k_proj): Linear(in_features=2048, out_features=2048, bias=False)
#             (v_proj): Linear(in_features=2048, out_features=2048, bias=False)
#             (q_proj): Linear(in_features=2048, out_features=2048, bias=False)
#             (out_proj): Linear(in_features=2048, out_features=2048, bias=True)
#           )
#         )
#         (ln_2): LayerNorm((2048,), eps=1e-05, elementwise_affine=True)
#         (mlp): GPTNeoMLP(
# ...

# %% [markdown]
# Write Code Generation Function

# %%
def generate_code(prompt, max_length=200):
    inputs = tokenizer(
        prompt,
        return_tensors="pt",
        padding=True
    )

    input_ids = inputs["input_ids"]
    attention_mask = inputs["attention_mask"]

    with torch.no_grad():
        output = model.generate(
            input_ids=input_ids,
            attention_mask=attention_mask,
            max_length=max_length,
            temperature=0.2,
            top_p=0.95,
            do_sample=True,
            pad_token_id=tokenizer.eos_token_id
        )

    return tokenizer.decode(output[0], skip_special_tokens=True)

# %%
# Fix tokenizer padding issue for GPT-Neo
tokenizer.pad_token = tokenizer.eos_token

# %% [markdown]
# Test the Generator

# %%
tasks = [
    "Write a Python function to check if a number is even",
    "Write a Python function to compute factorial using recursion",
    "Write a Python function to reverse a string",
    "Write a Python function to find the maximum element in a list"
]

for task in tasks:
    print("=" * 60)
    print(f"Task: {task}\n")
    print(generate_code(task))
# Out:
# ...
# Task: Write a Python function to check if a number is even
#
# Write a Python function to check if a number is even or odd
#
# I have a function that checks if a number is even or odd. I want to write a function that checks if a number is even or odd in Python.
# I have tried the following:
# def is_even(n):
#     if n % 2 == 0:
#         return True
#     else:
#         return False
#
# But I get the following error:
# TypeError: 'int' object is not iterable
#
# A:
#
# You can use the built-in function is_odd to check if a number is odd.
# def is_odd(n):
#     if n % 2 != 0:
#         return False
#     else:
#         return True
#
# A:
#
# You can use the
# ...
# Task: Write a Python function to compute factorial using recursion
#
# Write a Python function to compute factorial using recursion
#
# I have a Python function that computes the factorial of a number. I want to write a function that computes the factorial of a number using recursion.
# ...
